# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\gabri\onedrive\desktop\prjt-eleflow\.conda\lib\site-packages (2.1.1)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\gabri\onedrive\desktop\prjt-eleflow\.conda\lib\site-packages (from pandas) (1.26.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\gabri\onedrive\desktop\prjt-eleflow\.conda\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gabri\onedrive\desktop\prjt-eleflow\.conda\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\gabri\onedrive\desktop\prjt-eleflow\.conda\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\gabri\onedrive\desktop\prjt-eleflow\.conda\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
# !pip install unicode
# Out:
# Requirement already satisfied: unicode in c:\users\gabri\onedrive\desktop\prjt-eleflow\.conda\lib\site-packages (2.9)

# %%
from unidecode import unidecode
import re
# função responsável por realizar snake_case
def snake_case(text:str) -> str:
    
    return unidecode(text.replace(" ","_").lower()) if " " in text else re.sub(r'([a-z0-9])([A-Z])', r'\1_\2', unidecode(text.replace("ICAO", "icao_"))).lower()

# %%
import pandas as pd
import os

# criando variáveis com diretórios arquivo de air_cia
air_cia_input_path = list(map(lambda item: "./AIR_CIA/"+item, os.listdir("./AIR_CIA/")))
air_cia_raw_path = "raw/air_cia.csv"
air_cia_clean_path = "clean/air_cia.csv"
air_cia_curated_path = "curated/air_cia.csv"

dfs = []

# realizando a leitura dos arquivos csv de air_cia e os listando
for file in air_cia_input_path:
    df = pd.read_csv(file, delimiter=';')
    dfs.append(df)

#unificando lista de dataframes dos dados
df_air_cia = pd.concat(dfs, ignore_index=True)

#checando se diretório existe e o criando caso não, para garantir funcionamento
if not os.path.exists("raw"):
    os.makedirs("raw")

#escrevendo os dados na camada bronze
df_air_cia.to_csv(air_cia_raw_path, index=False, sep=';', encoding='utf-8')

# realizando a leitura dos dados da camada bronze
df_air_cia_clean = pd.read_csv("./"+air_cia_raw_path, delimiter=';')

# aplicando snake_case em nomes de colunas
df_air_cia_clean.rename(columns=lambda x: snake_case(x), inplace=True)

if not os.path.exists("clean"):
    os.makedirs("clean")

#salvando os dados na camada prata
df_air_cia_clean.to_csv(air_cia_clean_path, index=False, sep=';', encoding='utf-8')

#realizando a leitura de dados da camada prata
df_air_cia_curated = pd.read_csv("./"+air_cia_clean_path, delimiter=';')

#separando as colunas de ICAO e de IATA
df_air_cia_curated[['icao','iata']] = df_air_cia_curated["icao_iata"].str.split(' ', expand=True)

if not os.path.exists("curated"):
    os.makedirs("curated")

#gravando os dados na camada ouro
df_air_cia_curated.to_csv(air_cia_curated_path, index=False, sep=';', encoding='utf-8')

# %%
# criando variáveis com diretórios de uso de VRA
vra_input_path = list(map(lambda item: "./VRA/"+item, os.listdir("./VRA/")))
vra_raw_path = "raw/vra.csv"
vra_clean_path = "clean/vra.csv"

dfs = []

#percorrendo lista de arquivos de VRA, transformando em DF pandas e os listando
for file in vra_input_path:
    df = pd.read_json(file, encoding = 'utf-8-sig')
    dfs.append(df)

#concatenando lista de DFs de VRA
df_vra_raw = pd.concat(dfs, ignore_index=True)

if not os.path.exists("raw"):
    os.makedirs("raw")

#salvando df em camada bronze
df_vra_raw.to_csv(vra_raw_path, index=False, sep=';', encoding='utf-8')

#realizando a leitura do arquivo da camada bronze
df_vra_clean = pd.read_csv("./"+vra_raw_path, delimiter=';')

# aplicando snake_case em nomes de colunas
df_vra_clean.rename(columns=lambda x: snake_case(x), inplace=True)

if not os.path.exists("clean"):
    os.makedirs("clean")

# escrevendo dados na camada prata
df_vra_clean.to_csv(vra_clean_path, index=False, sep=';', encoding='utf-8')
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_16496\1367554861.py:18: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_vra_clean = pd.read_csv("./"+vra_raw_path, delimiter=';')

# %%
import requests
import json

aerodromo_info_raw_path = "raw/aerodromo_info.csv"
aerodromo_info_clean_path = "clean/aerodromo_info.csv"

# url de chamada
url = "https://airport-info.p.rapidapi.com/airport"

# header com dados de autenticação
headers = {
	"X-RapidAPI-Key": "d7d32e551bmsh0fbf0c07b7c7057p107255jsndd38c5445b21",
	"X-RapidAPI-Host": "airport-info.p.rapidapi.com"
}

# leitura de VRA com dados de ICAO
df_vra_clean = pd.read_csv("./"+vra_clean_path, delimiter=';')

#listando dados de ICAO
lista_icao_aerodromo_origem = df_vra_clean['icao_aerodromo_origem'].tolist()
lista_icao_aerodromo_destino = df_vra_clean['icao_aerodromo_destino'].tolist()

#unindo listas com o auxilio de SET para não ser realizzado a chamada da API de forma repetida 
lista_icao = list(set(lista_icao_aerodromo_origem + lista_icao_aerodromo_destino))

dfs = []
i = 0

# laço de repetição com chamada de API e criação de query string com resultado de ICAO 
for icao in lista_icao:
    querystring = {"icao":icao}
    # chamada de API com resultados
    response = requests.get(url, headers=headers, params=querystring)
    # checando valores de chamadas para checar sucesso de chamada
    if response.status_code == 200 and 'error' not in response.text:
        # realizando parse de resultado de chamda da API para JSON
        data = json.loads(response.text)
        df = pd.DataFrame(data, index=[0])
        dfs.append(df)
    # print para acompanhamento de execução, existem 315 chamadas no total
    i+=1
    print("chamada de API número:"+str(i))

df_aerodromo_info = pd.concat(dfs, ignore_index=True)

if not os.path.exists("raw"):
    os.makedirs("raw")

#salvando df em camada bronze
df_aerodromo_info.to_csv(aerodromo_info_raw_path, index=False, sep=';', encoding='utf-8')

#realizando a leitura do arquivo da camada bronze
df_aerodromo_info_clean = pd.read_csv("./"+aerodromo_info_raw_path, delimiter=';')

# aplicando snake_case em nomes de colunas
df_aerodromo_info_clean.rename(columns=lambda x: snake_case(x), inplace=True)

if not os.path.exists("clean"):
    os.makedirs("clean")

# escrevendo dados na camada prata
df_aerodromo_info_clean.to_csv(aerodromo_info_clean_path, index=False, sep=';', encoding='utf-8')
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_16496\2205387299.py:17: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_vra_clean = pd.read_csv("./"+vra_clean_path, delimiter=';')
# chamada de API número:1
# chamada de API número:2
# chamada de API número:3
# chamada de API número:4
# chamada de API número:5
# chamada de API número:6
# chamada de API número:7
# chamada de API número:8
# chamada de API número:9
# chamada de API número:10
# chamada de API número:11
# chamada de API número:12
# chamada de API número:13
# chamada de API número:14
# chamada de API número:15
# chamada de API número:16
# chamada de API número:17
# chamada de API número:18
# chamada de API número:19
# chamada de API número:20
# chamada de API número:21
# chamada de API número:22
# chamada de API número:23
# chamada de API número:24
# chamada de API número:25
# chamada de API número:26
# chamada de API número:27
# chamada de API número:28
# chamada de API número:29
# chamada de API número:30
# chamada de API número:31
# chamada de API número:32
# chamada de API número:33
# chamada de API número:34
# chamada de API número:35
# chamada de API número:36
# chamada de API número:37
# chamada de API número:38
# chamada de API número:39
# chamada de API número:40
# chamada de API número:41
# chamada de API número:42
# chamada de API número:43
# chamada de API número:44
# chamada de API número:45
# chamada de API número:46
# chamada de API número:47
# chamada de API número:48
# chamada de API número:49
# chamada de API número:50
# chamada de API número:51
# chamada de API número:52
# chamada de API número:53
# chamada de API número:54
# chamada de API número:55
# chamada de API número:56
# chamada de API número:57
# chamada de API número:58
# chamada de API número:59
# chamada de API número:60
# chamada de API número:61
# chamada de API número:62
# chamada de API número:63
# chamada de API número:64
# chamada de API número:65
# chamada de API número:66
# chamada de API número:67
# chamada de API número:68
# chamada de API número:69
# chamada de API número:70
# chamada de API número:71
# chamada de API número:72
# chamada de API número:73
# chamada de API número:74
# chamada de API número:75
# chamada de API número:76
# chamada de API número:77
# chamada de API número:78
# chamada de API número:79
# chamada de API número:80
# chamada de API número:81
# chamada de API número:82
# chamada de API número:83
# chamada de API número:84
# chamada de API número:85
# chamada de API número:86
# chamada de API número:87
# chamada de API número:88
# chamada de API número:89
# chamada de API número:90
# chamada de API número:91
# chamada de API número:92
# chamada de API número:93
# chamada de API número:94
# chamada de API número:95
# chamada de API número:96
# chamada de API número:97
# chamada de API número:98
# chamada de API número:99
# chamada de API número:100
# chamada de API número:101
# chamada de API número:102
# chamada de API número:103
# chamada de API número:104
# chamada de API número:105
# chamada de API número:106
# chamada de API número:107
# chamada de API número:108
# chamada de API número:109
# chamada de API número:110
# chamada de API número:111
# chamada de API número:112
# chamada de API número:113
# chamada de API número:114
# chamada de API número:115
# chamada de API número:116
# chamada de API número:117
# chamada de API número:118
# chamada de API número:119
# chamada de API número:120
# chamada de API número:121
# chamada de API número:122
# chamada de API número:123
# chamada de API número:124
# chamada de API número:125
# chamada de API número:126
# chamada de API número:127
# chamada de API número:128
# chamada de API número:129
# chamada de API número:130
# chamada de API número:131
# chamada de API número:132
# chamada de API número:133
# chamada de API número:134
# chamada de API número:135
# chamada de API número:136
# chamada de API número:137
# chamada de API número:138
# chamada de API número:139
# chamada de API número:140
# chamada de API número:141
# chamada de API número:142
# chamada de API número:143
# chamada de API número:144
# chamada de API número:145
# chamada de API número:146
# chamada de API número:147
# chamada de API número:148
# chamada de API número:149
# chamada de API número:150
# chamada de API número:151
# chamada de API número:152
# chamada de API número:153
# chamada de API número:154
# chamada de API número:155
# chamada de API número:156
# chamada de API número:157
# chamada de API número:158
# chamada de API número:159
# chamada de API número:160
# chamada de API número:161
# chamada de API número:162
# chamada de API número:163
# chamada de API número:164
# chamada de API número:165
# chamada de API número:166
# chamada de API número:167
# chamada de API número:168
# chamada de API número:169
# chamada de API número:170
# chamada de API número:171
# chamada de API número:172
# chamada de API número:173
# chamada de API número:174
# chamada de API número:175
# chamada de API número:176
# chamada de API número:177
# chamada de API número:178
# chamada de API número:179
# chamada de API número:180
# chamada de API número:181
# chamada de API número:182
# chamada de API número:183
# chamada de API número:184
# chamada de API número:185
# chamada de API número:186
# chamada de API número:187
# chamada de API número:188
# chamada de API número:189
# chamada de API número:190
# chamada de API número:191
# chamada de API número:192
# chamada de API número:193
# chamada de API número:194
# chamada de API número:195
# chamada de API número:196
# chamada de API número:197
# chamada de API número:198
# chamada de API número:199
# chamada de API número:200
# chamada de API número:201
# chamada de API número:202
# chamada de API número:203
# chamada de API número:204
# chamada de API número:205
# chamada de API número:206
# chamada de API número:207
# chamada de API número:208
# chamada de API número:209
# chamada de API número:210
# chamada de API número:211
# chamada de API número:212
# chamada de API número:213
# chamada de API número:214
# chamada de API número:215
# chamada de API número:216
# chamada de API número:217
# chamada de API número:218
# chamada de API número:219
# chamada de API número:220
# chamada de API número:221
# chamada de API número:222
# chamada de API número:223
# chamada de API número:224
# chamada de API número:225
# chamada de API número:226
# chamada de API número:227
# chamada de API número:228
# chamada de API número:229
# chamada de API número:230
# chamada de API número:231
# chamada de API número:232
# chamada de API número:233
# chamada de API número:234
# chamada de API número:235
# chamada de API número:236
# chamada de API número:237
# chamada de API número:238
# chamada de API número:239
# chamada de API número:240
# chamada de API número:241
# chamada de API número:242
# chamada de API número:243
# chamada de API número:244
# chamada de API número:245
# chamada de API número:246
# chamada de API número:247
# chamada de API número:248
# chamada de API número:249
# chamada de API número:250
# chamada de API número:251
# chamada de API número:252
# chamada de API número:253
# chamada de API número:254
# chamada de API número:255
# chamada de API número:256
# chamada de API número:257
# chamada de API número:258
# chamada de API número:259
# chamada de API número:260
# chamada de API número:261
# chamada de API número:262
# chamada de API número:263
# chamada de API número:264
# chamada de API número:265
# chamada de API número:266
# chamada de API número:267
# chamada de API número:268
# chamada de API número:269
# chamada de API número:270
# chamada de API número:271
# chamada de API número:272
# chamada de API número:273
# chamada de API número:274
# chamada de API número:275
# chamada de API número:276
# chamada de API número:277
# chamada de API número:278
# chamada de API número:279
# chamada de API número:280
# chamada de API número:281
# chamada de API número:282
# chamada de API número:283
# chamada de API número:284
# chamada de API número:285
# chamada de API número:286
# chamada de API número:287
# chamada de API número:288
# chamada de API número:289
# chamada de API número:290
# chamada de API número:291
# chamada de API número:292
# chamada de API número:293
# chamada de API número:294
# chamada de API número:295
# chamada de API número:296
# chamada de API número:297
# chamada de API número:298
# chamada de API número:299
# chamada de API número:300
# chamada de API número:301
# chamada de API número:302
# chamada de API número:303
# chamada de API número:304
# chamada de API número:305
# chamada de API número:306
# chamada de API número:307
# chamada de API número:308
# chamada de API número:309
# chamada de API número:310
# chamada de API número:311
# chamada de API número:312
# chamada de API número:313
# chamada de API número:314
# chamada de API número:315
# C:\Users\gabri\AppData\Local\Temp\ipykernel_16496\2205387299.py:53: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_aerodromo_info_clean = pd.read_csv("./"+vra_raw_path, delimiter=';')

# %%
#### Extras:
#   - Descrever qual estratégia você usaria para ingerir estes dados de forma incremental caso precise capturar esses dados a cada mes?
#   Resposta: identificaria o campo incremental e realizaria a leitura por ele, de forama a escrever os dados particionados pelo campo incremental também.
#   - Justifique em cada etapa sobre a escalabilidade da tecnologia utilizada.
#   Resposta: A tecnologia escolhida não possui escabilidade, por ter sido desenvolvido de forma local e com o uso de pandas para explorar os dados, este tem o beneficio de baixo custo, também podendo ser inserido em ferramentas serveless em núvem mantendo o baixo custo, para se obter escabilidade poderá ser desenvolvido com o uso de pyspark e com o uso do Databricks ou com o uso de ferramentas de dados em núvem como Databricks ou Synape no caso de Azure
#   - Justifique as camadas utilizadas durante o processo de ingestão até a disponibilização dos dados.
#   Resposta: foi utilizado um modelo de datalake para a construção das camadas, de forma a raw(bronze) possuir os dados de forma crua, assim como são ingeridos, de forma a considerar a sua entrada apenas após o processamento, a camada clean(prata) é responsável por conter dados após limpeza e/ou normalização, como a única normalização necessária foi a dos cabeçalhos esta foi aplicada para esta camada, por último a camada curated(ouro), está possui informações de dados curados, que possuem unificações e um certo nível de tratativas, desta forma os dados de AIR_CIA foram os únicos que precisaram de algum tipo de modificação, desta forma este foi escolhido para esta mas apenas neste caso em especifico.

# %%
## conexão com banco de dados para inserção de dados.
## banco de dados esta em container docker

# %%
# !pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in c:\users\gabri\onedrive\desktop\prjt-eleflow\.conda\lib\site-packages (2.0.22)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\gabri\onedrive\desktop\prjt-eleflow\.conda\lib\site-packages (from sqlalchemy) (4.8.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\gabri\onedrive\desktop\prjt-eleflow\.conda\lib\site-packages (from sqlalchemy) (3.0.0)

# %%
# !pip install psycopg2
# Out:
# Collecting psycopg2
#   Obtaining dependency information for psycopg2 from https://files.pythonhosted.org/packages/bc/bc/6572dec6834e779668421e25f8812a872d978e241f85491a5e4dda606a98/psycopg2-2.9.9-cp310-cp310-win_amd64.whl.metadata
#   Downloading psycopg2-2.9.9-cp310-cp310-win_amd64.whl.metadata (4.5 kB)
# Downloading psycopg2-2.9.9-cp310-cp310-win_amd64.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    -- ------------------------------------- 0.1/1.2 MB 544.7 kB/s eta 0:00:03
#    ------------------- -------------------- 0.6/1.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  1.2/1.2 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 5.7 MB/s eta 0:00:00
# Installing collected packages: psycopg2
# Successfully installed psycopg2-2.9.9

# %%
from sqlalchemy import create_engine

db_user = "postgre"
db_password = "pass123"
db_host = "localhost"
db_port = "5432"
db_name = "aerodromo"

connection_string = f"postgresql://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}"
engine = create_engine(connection_string)

# %%
df_aerodromo_info_clean = pd.read_csv("./"+aerodromo_info_clean_path, delimiter=';')

table_name = 'aerodromo_info'

df_aerodromo_info_clean.to_sql(table_name, engine, index=False)
# Out:
# 276

# %%
df_vra_clean = pd.read_csv("./"+vra_clean_path, delimiter=';')

table_name = 'vra'

df_vra_clean.to_sql(table_name, engine, index=False)
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_16496\4034603696.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_vra_clean = pd.read_csv("./"+vra_clean_path, delimiter=';')
# 803

# %%
df_air_cia_curated = pd.read_csv("./"+air_cia_curated_path, delimiter=';')

table_name = 'air_cia'

df_air_cia_curated.to_sql(table_name, engine, index=False)
# Out:
# 20
